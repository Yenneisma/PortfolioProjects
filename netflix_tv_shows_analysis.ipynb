# %% [markdown]
# # What TV shows are the most popular on Netflix?

# %% [markdown]
# 1. Introduction

# %% [markdown]
# *Data source:*

# %%
import kagglehub
path = kagglehub.dataset_download("shivamb/netflix-shows")

print("done")
# Out:
# Using Colab cache for faster access to the 'netflix-shows' dataset.
# done
